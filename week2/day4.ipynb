# %% [markdown]
# # Project - Airline AI Assistant
#
# We'll now bring together what we've learned to make an AI Customer Support assistant for an Airline

# %%
# imports

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr
import sqlite3

# %%
# Initialization

load_dotenv(override=True)

openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
MODEL = "gpt-4o-mini"
openai = OpenAI()

# As an alternative, if you'd like to use Ollama instead of OpenAI
# Check that Ollama is running for you locally (see week1/day2 exercise) then uncomment these next 2 lines
# MODEL = "llama3.2"
# openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
system_message = "You are a helpful assistant for an Airline and Hotel Managenment Company called FlightAI. "
system_message += "Give short, courteous answers, no more than 1 sentence. "
system_message += "Always be accurate. If you don't know the answer, say so."

# %%
# This function looks rather simpler than the one from my video, because we're taking advantage of the latest Gradio updates

def chat(message, history):
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=MODEL, messages=messages)
    return response.choices[0].message.content

gr.ChatInterface(fn=chat, type="messages").launch()

# %% [markdown]
# ## Tools
#
# Tools are an incredibly powerful feature provided by the frontier LLMs.
#
# With tools, you can write a function, and have the LLM call that function as part of its response.
#
# Sounds almost spooky.. we're giving it the power to run code on our machine?
#
# Well, kinda.

# %%
# Let's start by making a useful function

ticket_prices = {"london": "$799", "paris": "$899", "tokyo": "$1400", "berlin": "$499"}

def get_ticket_price(destination_city):
    print(f"Tool get_ticket_price called for {destination_city}")
    city = destination_city.lower()
    return ticket_prices.get(city, "Unknown")

# %%
def get_hotel_price(destination_city):
    print(f"Tool get_hotel_price called for {destination_city}")
    city = destination_city.lower()
    return ticket_prices.get(city, "Unknown")

# %%
get_ticket_price("Berlin")
# Out:
# Tool get_ticket_price called for Berlin
# '$499'

# %%
# There's a particular dictionary structure that's required to describe our function:

price_function = {
    "name": "get_ticket_price",
    "description": "Get the price of a return ticket to the destination city. Call this whenever you need to know the ticket price, for example when a customer asks 'How much is a ticket to this city'",
    "parameters": {
        "type": "object",
        "properties": {
            "destination_city": {
                "type": "string",
                "description": "The city that the customer wants to travel to",
            },
        },
        "required": ["destination_city"],
        "additionalProperties": False
    }
}

# %%
# There's a particular dictionary structure that's required to describe our function:

hotel_price_function = {
    "name": "get_hotel_price",
    "description": "Get the price of a hotel charges to the destination city. Call this whenever you need to know the hotel price, for example when a customer asks 'How much does hotel charges in this city'",
    "parameters": {
        "type": "object",
        "properties": {
            "destination_city": {
                "type": "string",
                "description": "The city that the customer wants to travel to",
            },
        },
        "required": ["destination_city"],
        "additionalProperties": False
    }
}

# %%
# And this is included in a list of tools:

tools = [{"type": "function", "function": price_function}, {"type": "function", "function": hotel_price_function}]
# Out:
# [{'role': 'system', 'content': "You are a helpful assistant for an Airline and Hotel Managenment Company called FlightAI. Give short, courteous answers, no more than 1 sentence. Always be accurate. If you don't know the answer, say so."}, {'role': 'user', 'metadata': None, 'content': 'Hello I am planning to visit berlin, what will be hotel prices?', 'options': None}, {'role': 'user', 'content': 'Retry'}]
# ChatCompletion(id='chatcmpl-BmvBqHUdK3QyRRPUuzX83daFA250R', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_Ai5ozH8pFlB0EmAga14N37Ae', function=Function(arguments='{"destination_city":"Berlin"}', name='get_hotel_price'), type='function')]))], created=1750999282, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=CompletionUsage(completion_tokens=17, prompt_tokens=220, total_tokens=237, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_Ai5ozH8pFlB0EmAga14N37Ae', function=Function(arguments='{"destination_city":"Berlin"}', name='get_hotel_price'), type='function')])

# %% [markdown]
# ## Getting OpenAI to use our Tool
#
# There's some fiddly stuff to allow OpenAI "to call our tool"
#
# What we actually do is give the LLM the opportunity to inform us that it wants us to run the tool.
#
# Here's how the new chat function looks:

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    print(messages)
    response = openai.chat.completions.create(model=MODEL, messages=messages, tools=tools)
    print(response)
    if response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        multi_response, city = handle_tool_call(message)
        messages.append(message)
        for response in multi_response:
            messages.append(response)
        response = openai.chat.completions.create(model=MODEL, messages=messages)
    
    return response.choices[0].message.content

# %%
# We have to write that function handle_tool_call:

def handle_tool_call(message):
    print(message)
    # tool_call = message.tool_calls[0]
    response = []
    for tool_call in message.tool_calls:
        arguments = json.loads(tool_call.function.arguments)
        # print(arguments)
        city = arguments.get('destination_city')
        function_tool_call = tool_call.function.name
        print(function_tool_call, city)
        if function_tool_call == 'get_ticket_price':
            price = get_ticket_price(city)
        else:
            price = get_hotel_price(city)
        response.append({
            "role": "tool",
            "content": json.dumps({"destination_city": city,"price": price}),
            "tool_call_id": tool_call.id
        })
    return response, city

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7882
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7882/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# [{'role': 'system', 'content': "You are a helpful assistant for an Airline and Hotel Managenment Company called FlightAI. Give short, courteous answers, no more than 1 sentence. Always be accurate. If you don't know the answer, say so."}, {'role': 'user', 'content': 'plane and hotel price london'}]
# ChatCompletion(id='chatcmpl-BmvMdcp6yaRZdMfBNAFu87RR4Vdcd', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_tMMtRp78Ml8R6PQoL4KPRfqs', function=Function(arguments='{"destination_city": "London"}', name='get_ticket_price'), type='function'), ChatCompletionMessageToolCall(id='call_jL8A4k5xE656p57Qy7s2lSmU', function=Function(arguments='{"destination_city": "London"}', name='get_hotel_price'), type='function')]))], created=1750999951, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=CompletionUsage(completion_tokens=49, prompt_tokens=206, total_tokens=255, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_tMMtRp78Ml8R6PQoL4KPRfqs', function=Function(arguments='{"destination_city": "London"}', name='get_ticket_price'), type='function'), ChatCompletionMessageToolCall(id='call_jL8A4k5xE656p57Qy7s2lSmU', function=Function(arguments='{"destination_city": "London"}', name='get_hotel_price'), type='function')])
# get_ticket_price London
# Tool get_ticket_price called for London
# get_hotel_price London
# Tool get_hotel_price called for London
# [{'role': 'system', 'content': "You are a helpful assistant for an Airline and Hotel Managenment Company called FlightAI. Give short, courteous answers, no more than 1 sentence. Always be accurate. If you don't know the answer, say so."}, {'role': 'user', 'metadata': None, 'content': 'plane and hotel price london', 'options': None}, {'role': 'assistant', 'metadata': None, 'content': 'The price for a plane ticket to London is $799, and hotel prices in London also start at $799.', 'options': None}, {'role': 'user', 'content': 'plane price for london and hotel price for berlin'}]
# ChatCompletion(id='chatcmpl-BmvN8HloKRXPbP9a1ZZyqcT0RLb3p', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_4TgX3e2hjpGCEJG4wNO7pFoh', function=Function(arguments='{"destination_city": "London"}', name='get_ticket_price'), type='function'), ChatCompletionMessageToolCall(id='call_ZQhtn9t98xoBE2LopwCWLlWB', function=Function(arguments='{"destination_city": "Berlin"}', name='get_hotel_price'), type='function')]))], created=1750999982, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=CompletionUsage(completion_tokens=49, prompt_tokens=246, total_tokens=295, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_4TgX3e2hjpGCEJG4wNO7pFoh', function=Function(arguments='{"destination_city": "London"}', name='get_ticket_price'), type='function'), ChatCompletionMessageToolCall(id='call_ZQhtn9t98xoBE2LopwCWLlWB', function=Function(arguments='{"destination_city": "Berlin"}', name='get_hotel_price'), type='function')])
# get_ticket_price London
# Tool get_ticket_price called for London
# get_hotel_price Berlin
# Tool get_hotel_price called for Berlin

# %%
con = sqlite3.connect('flight_data.db')
cur = con.cursor()
cur.execute('''Drop Table flight_data;''')
con.commit()
con.close()

# %%
con = sqlite3.connect('flight_data.db')
cur = con.cursor()
cur.execute('''CREATE TABLE flight_data (
    id SERIAL PRIMARY KEY,                      -- Auto-increment ID for each record
    airline VARCHAR(100) NOT NULL,              -- Name of the airline
    flight VARCHAR(50) NOT NULL,                -- Flight number/code
    source_city VARCHAR(100) NOT NULL,          -- City of departure
    departure_time TIME NOT NULL,               -- Scheduled departure time
    stops VARCHAR(50),                          -- Number/type of stops (e.g., 'non-stop', '1 stop')
    arrival_time TIME NOT NULL,                 -- Scheduled arrival time
    destination_city VARCHAR(100) NOT NULL,     -- City of arrival
    class VARCHAR(50) NOT NULL,                 -- Travel class (e.g., Economy, Business)
    duration INTERVAL,                          -- Duration of the flight (e.g., '2 hours 30 minutes')
    days_left INT CHECK (days_left >= 0),       -- Days left until departure
    price DECIMAL(10, 2) NOT NULL               -- Ticket price
);''')
con.commit()
con.close()

# %%
con = sqlite3.connect('flight_data.db')
cur = con.cursor()
for row in cur.execute("select * from flight_data"):
    print(row)
# Out:
# (None, 'SpiceJet', 'SG-8709', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 1, 5953)
# (None, 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 1, 5953)
# (None, 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning', 'Mumbai', 'Economy', 2.17, 1, 5956)
# (None, 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.25, 1, 5955)
# (None, 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 1, 5955)
# (None, 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 1, 5955)
# (None, 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.08, 1, 6060)
# (None, 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 1, 6060)
# (None, 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 1, 5954)
# (None, 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 1, 5954)
# (None, 'GO_FIRST', 'G8-392', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 1, 5954)
# (None, 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 1, 5954)
# (None, 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 1, 5955)
# (None, 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.17, 1, 5955)
# (None, 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 1, 5955)
# (None, 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 1, 5955)
# (None, 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.08, 1, 5955)
# (None, 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 1, 5955)
# (None, 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 12.25, 1, 5949)
# (None, 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 16.33, 1, 5949)
# (None, 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 11.75, 1, 5954)
# (None, 'GO_FIRST', 'G8-101', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 14.5, 1, 5954)
# (None, 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.67, 1, 5954)
# (None, 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 3.75, 1, 5955)
# (None, 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.5, 1, 6165)
# (None, 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 1, 6690)
# (None, 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 1, 6585)
# (None, 'AirAsia', 'I5-744', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 5.83, 1, 8869)
# (None, 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 1, 10260)
# (None, 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 1, 10470)
# (None, 'GO_FIRST', 'G8-165', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 8, 1, 10575)
# (None, 'Indigo', '6E-2373', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 6, 1, 10838)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 14.67, 1, 12150)
# (None, 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 16.17, 1, 12150)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Morning', 'Mumbai', 'Economy', 18, 1, 12150)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 23.17, 1, 12150)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 24.17, 1, 12150)
# (None, 'Air_India', 'AI-453', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 8.83, 1, 11900)
# (None, 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.5, 1, 12123)
# (None, 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.25, 1, 12123)
# (None, 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 11, 1, 12150)
# (None, 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Morning', 'Mumbai', 'Economy', 19.08, 1, 12150)
# (None, 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 22.83, 1, 12150)
# (None, 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 26.42, 1, 12150)
# (None, 'Air_India', 'AI-479', 'Delhi', 'Night', 'one', 'Afternoon', 'Mumbai', 'Economy', 17.75, 1, 12215)
# (None, 'SpiceJet', 'SG-339', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 19.58, 1, 12230)
# (None, 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 1, 12780)
# (None, 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 26.67, 1, 12885)
# (None, 'AirAsia', 'I5-784', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 15.17, 1, 12539)
# (None, 'Air_India', 'AI-9643', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 20.83, 1, 12938)
# (None, 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 11.42, 1, 12990)
# (None, 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 22.25, 1, 12990)
# (None, 'Air_India', 'AI-439', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 26, 1, 12990)
# (None, 'Air_India', 'AI-9645', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 21.75, 1, 13086)
# (None, 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 3.83, 1, 13279)
# (None, 'Indigo', '6E-2168', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.42, 1, 13279)
# (None, 'Indigo', '6E-152', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 7.67, 1, 13279)
# (None, 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8.33, 1, 13279)
# (None, 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 10.42, 1, 13279)
# (None, 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 23.75, 1, 13673)
# (None, 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 19.5, 1, 13410)
# (None, 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 6.5, 1, 13935)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 12.42, 1, 14040)
# (None, 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 21.08, 1, 14040)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 26.67, 1, 14093)
# (None, 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 28.17, 1, 14093)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 28.25, 1, 14093)
# (None, 'Indigo', '6E-2338', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8, 1, 13767)
# (None, 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 9.25, 1, 13932)
# (None, 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Afternoon', 'Mumbai', 'Economy', 17.92, 1, 14408)
# (None, 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 26.42, 1, 14408)
# (None, 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Afternoon', 'Mumbai', 'Economy', 16.17, 1, 14250)
# (None, 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 7.08, 1, 14539)
# (None, 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 13.83, 1, 14985)
# (None, 'Air_India', 'AI-512', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.58, 1, 14670)
# (None, 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.83, 1, 15195)
# (None, 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 1, 15720)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 24.42, 1, 15983)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 26, 1, 15983)
# (None, 'Indigo', '6E-184', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 4.17, 1, 15720)
# (None, 'SpiceJet', 'SG-3002', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 4.25, 1, 15720)
# (None, 'Indigo', '6E-2102', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 5.08, 1, 15720)
# (None, 'Air_India', 'AI-801', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 29.33, 1, 16245)
# (None, 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.42, 1, 16613)
# (None, 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 17, 1, 16665)
# (None, 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 26.67, 1, 16665)
# (None, 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 27.17, 1, 16455)
# (None, 'Air_India', 'AI-531', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 24.75, 1, 16665)
# (None, 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 5.75, 1, 17348)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.58, 1, 17348)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.75, 1, 17348)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 13.75, 1, 17348)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 17.83, 1, 17348)
# (None, 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 5.5, 1, 17400)
# (None, 'Vistara', 'UK-707', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 19.5, 1, 17505)
# (None, 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.58, 1, 17610)
# (None, 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 23.83, 1, 17295)
# (None, 'Vistara', 'UK-673', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 5, 1, 17663)
# (None, 'Air_India', 'AI-839', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 26.5, 1, 18030)
# (None, 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 20.83, 1, 18398)
# (None, 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.83, 1, 18450)
# (None, 'GO_FIRST', 'G8-191', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 8.92, 1, 18487)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 6, 1, 18923)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 11.17, 1, 18923)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.17, 1, 18923)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.58, 1, 19238)
# (None, 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.75, 1, 19920)
# (None, 'Air_India', 'AI-767', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.92, 1, 19710)
# (None, 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 13.25, 1, 19710)
# (None, 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 16, 1, 20130)
# (None, 'Air_India', 'AI-473', 'Delhi', 'Evening', 'one', 'Evening', 'Mumbai', 'Economy', 22.75, 1, 19815)
# (None, 'Vistara', 'UK-707', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 6, 1, 21075)
# (None, 'GO_FIRST', 'G8-213', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 6.33, 1, 21111)
# (None, 'Air_India', 'AI-409', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 7.25, 1, 23206)
# (None, 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 30.08, 1, 24540)
# (None, 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 11, 1, 25800)
# (None, 'Vistara', 'UK-837', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 18.25, 1, 27270)
# (None, 'Air_India', 'AI-877', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 6.08, 1, 29580)
# (None, 'SpiceJet', 'SG-8803', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.25, 2, 5953)
# (None, 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 2, 5953)
# (None, 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.08, 2, 5955)
# (None, 'Vistara', 'UK-985', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 2, 5955)
# (None, 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 2, 5955)
# (None, 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 2, 5955)
# (None, 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 2, 5955)
# (None, 'Vistara', 'UK-953', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 2, 6060)
# (None, 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 2, 5954)
# (None, 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 2, 5954)
# (None, 'GO_FIRST', 'G8-346', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 2, 5954)
# (None, 'GO_FIRST', 'G8-330', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 2, 5954)
# (None, 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 2, 5954)
# (None, 'GO_FIRST', 'G8-323', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 2, 5954)
# (None, 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 2, 5955)
# (None, 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 2, 5955)
# (None, 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 2, 5955)
# (None, 'Indigo', '6E-218', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.25, 2, 5955)
# (None, 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 2, 5955)
# (None, 'Indigo', '6E-6722', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 2, 5955)
# (None, 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 2, 5955)
# (None, 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 2, 5955)
# (None, 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.5, 2, 5955)
# (None, 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning', 'Mumbai', 'Economy', 2.17, 2, 5956)
# (None, 'Air_India', 'AI-868', 'Delhi', 'Evening', 'zero', 'Evening', 'Mumbai', 'Economy', 2, 2, 5955)
# (None, 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.08, 2, 5955)
# (None, 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 2, 5955)
# (None, 'Air_India', 'AI-805', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 2, 5955)
# (None, 'Air_India', 'AI-624', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 2, 5955)
# (None, 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 12.25, 2, 5949)
# (None, 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 16.33, 2, 5949)
# (None, 'GO_FIRST', 'G8-188', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.33, 2, 5954)
# (None, 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 12.33, 2, 5954)
# (None, 'Air_India', 'AI-636', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 3.5, 2, 5955)
# (None, 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 3.75, 2, 5955)
# (None, 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.25, 2, 6375)
# (None, 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 2, 7530)
# (None, 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 2, 7530)
# (None, 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 2, 7530)
# (None, 'AirAsia', 'I5-784', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 15.17, 2, 7419)
# (None, 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.17, 2, 7845)
# (None, 'Indigo', '6E-2022', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 10.25, 2, 8396)
# (None, 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.5, 2, 8869)
# (None, 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.25, 2, 9183)
# (None, 'Air_India', 'AI-469', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 7.25, 2, 9840)
# (None, 'Air_India', 'AI-542', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 14.17, 2, 9840)
# (None, 'Air_India', 'AI-560', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 15.75, 2, 9840)
# (None, 'Vistara', 'UK-683', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 25.58, 2, 10566)
# (None, 'Air_India', 'AI-403', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 6.33, 2, 10303)
# (None, 'Indigo', '6E-2154', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 4.08, 2, 10523)
# (None, 'Air_India', 'AI-9843', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 9.75, 2, 10523)
# (None, 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 26.42, 2, 11048)
# (None, 'Indigo', '6E-2168', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.42, 2, 10838)
# (None, 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8.33, 2, 10838)
# (None, 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 10.42, 2, 10838)
# (None, 'Air_India', 'AI-544', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 6.67, 2, 11100)
# (None, 'Indigo', '6E-2338', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8, 2, 11326)
# (None, 'Indigo', '6E-282', 'Delhi', 'Morning', 'two_or_more', 'Evening', 'Mumbai', 'Economy', 9.67, 2, 11678)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 12.42, 2, 12150)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 14.67, 2, 12150)
# (None, 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 16.17, 2, 12150)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 24.17, 2, 12150)
# (None, 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 3.83, 2, 11814)
# (None, 'Indigo', '6E-152', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 7.67, 2, 11814)
# (None, 'Air_India', 'AI-453', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 10.08, 2, 11900)
# (None, 'Vistara', 'UK-859', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.58, 2, 12308)
# (None, 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.42, 2, 12570)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 23.17, 2, 12570)
# (None, 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 7, 2, 12623)
# (None, 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8.25, 2, 12623)
# (None, 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 15.5, 2, 12623)
# (None, 'Air_India', 'AI-9857', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 7.25, 2, 12298)
# (None, 'Indigo', '6E-607', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 10.17, 2, 12302)
# (None, 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 23.5, 2, 12465)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Morning', 'Mumbai', 'Economy', 18, 2, 12990)
# (None, 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Late_Night', 'Mumbai', 'Economy', 13.25, 2, 12675)
# (None, 'SpiceJet', 'SG-2277', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 25.75, 2, 12850)
# (None, 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 11.42, 2, 12990)
# (None, 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 11.5, 2, 12990)
# (None, 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Afternoon', 'Mumbai', 'Economy', 16.17, 2, 12990)
# (None, 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 19.5, 2, 12990)
# (None, 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 21.42, 2, 12990)
# (None, 'GO_FIRST', 'G8-719', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 14.25, 2, 13069)
# (None, 'GO_FIRST', 'G8-188', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 7.75, 2, 13321)
# (None, 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 5.33, 2, 13673)
# (None, 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 21.08, 2, 13830)
# (None, 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 5.75, 2, 14093)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.17, 2, 14093)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 13.75, 2, 14093)
# (None, 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.83, 2, 13830)
# (None, 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 11.75, 2, 14129)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 11.17, 2, 14513)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.75, 2, 14513)
# (None, 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 5.67, 2, 14250)
# (None, 'GO_FIRST', 'G8-119', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.17, 2, 14409)
# (None, 'GO_FIRST', 'G8-717', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.75, 2, 14487)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 6, 2, 14933)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.58, 2, 14933)
# (None, 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.92, 2, 15038)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.58, 2, 15353)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 17.83, 2, 15353)
# (None, 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 19.33, 2, 15353)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 26, 2, 15353)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 28.25, 2, 15353)
# (None, 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 7.08, 2, 15117)
# (None, 'Air_India', 'AI-439', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 26, 2, 15195)
# (None, 'Indigo', '6E-2102', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 5.08, 2, 15232)
# (None, 'Air_India', 'AI-465', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 6.25, 2, 15510)
# (None, 'Indigo', '6E-184', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 4.17, 2, 15720)
# (None, 'SpiceJet', 'SG-3002', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 4.25, 2, 15720)
# (None, 'Indigo', '6E-5018', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 10.33, 2, 15720)
# (None, 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 13.25, 2, 16035)
# (None, 'Vistara', 'UK-839', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 9.08, 2, 16560)
# (None, 'Vistara', 'UK-833', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 15.42, 2, 16560)
# (None, 'GO_FIRST', 'G8-165', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 8, 2, 16823)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 24.42, 2, 17348)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 26.67, 2, 17348)
# (None, 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 9.25, 2, 17136)
# (None, 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 23.83, 2, 18135)
# (None, 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 27.17, 2, 18135)
# (None, 'Vistara', 'UK-673', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 5, 2, 19343)
# (None, 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 26.67, 2, 19553)
# (None, 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 6.5, 2, 19815)
# (None, 'Air_India', 'AI-406', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 4.83, 2, 20445)
# (None, 'Air_India', 'AI-9809', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 25.83, 2, 21180)
# (None, 'Air_India', 'AI-512', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8.92, 2, 22335)
# (None, 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 7.5, 2, 23281)
# (None, 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 8.83, 2, 23281)
# (None, 'Vistara', 'UK-847', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 27.58, 2, 24488)
# (None, 'Air_India', 'AI-411', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 8, 2, 24855)
# (None, 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 28.42, 2, 25905)
# (None, 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 13.83, 2, 29160)
# (None, 'Air_India', 'AI-877', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 6.42, 2, 29580)
# (None, 'SpiceJet', 'SG-8803', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.25, 3, 5953)
# (None, 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 3, 5953)
# (None, 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 3, 5953)
# (None, 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.08, 3, 5955)
# (None, 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.25, 3, 5955)
# (None, 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 3, 5955)
# (None, 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 3, 5954)
# (None, 'GO_FIRST', 'G8-346', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 3, 5954)
# (None, 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 3, 5954)
# (None, 'GO_FIRST', 'G8-323', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 3, 5954)
# (None, 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 3, 5955)
# (None, 'Indigo', '6E-218', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.25, 3, 5955)
# (None, 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 3, 5955)
# (None, 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.5, 3, 5955)
# (None, 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning', 'Mumbai', 'Economy', 2.17, 3, 5956)
# (None, 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.08, 3, 5955)
# (None, 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 3, 5955)
# (None, 'Air_India', 'AI-805', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 3, 5955)
# (None, 'Air_India', 'AI-624', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 3, 5955)
# (None, 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 12.33, 3, 5954)
# (None, 'GO_FIRST', 'G8-113', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 15.75, 3, 5954)
# (None, 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 3.75, 3, 5955)
# (None, 'Vistara', 'UK-985', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 3, 6375)
# (None, 'SpiceJet', 'SG-8709', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 3, 6060)
# (None, 'SpiceJet', 'SG-8483', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 13.25, 3, 6270)
# (None, 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 3, 6690)
# (None, 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 3, 6532)
# (None, 'GO_FIRST', 'G8-330', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 3, 6532)
# (None, 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 3, 7005)
# (None, 'Air_India', 'AI-868', 'Delhi', 'Evening', 'zero', 'Evening', 'Mumbai', 'Economy', 2, 3, 6795)
# (None, 'GO_FIRST', 'G8-392', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 3, 7110)
# (None, 'Indigo', '6E-2022', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 10.25, 3, 7420)
# (None, 'Indigo', '6E-2154', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 5, 3, 7583)
# (None, 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.17, 3, 7845)
# (None, 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 3, 8055)
# (None, 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 3, 8370)
# (None, 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 3, 8370)
# (None, 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 3, 9525)
# (None, 'Vistara', 'UK-683', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 25.58, 3, 9988)
# (None, 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 12.25, 3, 9840)
# (None, 'Air_India', 'AI-475', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 24.58, 3, 9988)
# (None, 'Indigo', '6E-2373', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 6, 3, 10523)
# (None, 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 15.5, 3, 11048)
# (None, 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.25, 3, 10759)
# (None, 'Air_India', 'AI-531', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 24.75, 3, 10785)
# (None, 'GO_FIRST', 'G8-719', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 14.25, 3, 10863)
# (None, 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 10.42, 3, 10943)
# (None, 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Afternoon', 'Mumbai', 'Economy', 17.92, 3, 11415)
# (None, 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 20.83, 3, 11415)
# (None, 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 26.42, 3, 11415)
# (None, 'Indigo', '6E-2168', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.42, 3, 11326)
# (None, 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8.33, 3, 11326)
# (None, 'Air_India', 'AI-9643', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 20.83, 3, 11468)
# (None, 'Vistara', 'UK-859', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.58, 3, 12098)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 24.17, 3, 12150)
# (None, 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.5, 3, 11809)
# (None, 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 3.83, 3, 11814)
# (None, 'Indigo', '6E-152', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 7.67, 3, 11814)
# (None, 'Air_India', 'AI-479', 'Delhi', 'Night', 'one', 'Afternoon', 'Mumbai', 'Economy', 16.5, 3, 11900)
# (None, 'Indigo', '6E-181', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 4.83, 3, 11993)
# (None, 'SpiceJet', 'SG-2277', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 25.75, 3, 12010)
# (None, 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'two_or_more', 'Night', 'Mumbai', 'Economy', 11, 3, 12045)
# (None, 'GO_FIRST', 'G8-119', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.17, 3, 12045)
# (None, 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 11.33, 3, 12150)
# (None, 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 23.83, 3, 12150)
# (None, 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 26.42, 3, 12150)
# (None, 'GO_FIRST', 'G8-717', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.75, 3, 12229)
# (None, 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 5.33, 3, 12623)
# (None, 'Air_India', 'AI-9645', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 24.83, 3, 12298)
# (None, 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 3, 12780)
# (None, 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 14.92, 3, 12465)
# (None, 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 26.67, 3, 12885)
# (None, 'Indigo', '6E-2092', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 5.33, 3, 12570)
# (None, 'Indigo', '6E-5018', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 10.33, 3, 12570)
# (None, 'AirAsia', 'I5-784', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 15.17, 3, 12990)
# (None, 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 23.75, 3, 13410)
# (None, 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 5.08, 3, 13069)
# (None, 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 7.08, 3, 13069)
# (None, 'Air_India', 'AI-9911', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 26.08, 3, 13086)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 23.17, 3, 13515)
# (None, 'SpiceJet', 'SG-3002', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 4.25, 3, 13200)
# (None, 'Indigo', '6E-5063', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 5.42, 3, 13279)
# (None, 'Air_India', 'AI-411', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 8, 3, 13515)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 12.42, 3, 14040)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 24.42, 3, 14040)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 26, 3, 14040)
# (None, 'Indigo', '6E-2102', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 5.08, 3, 13767)
# (None, 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.42, 3, 14565)
# (None, 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.75, 3, 14565)
# (None, 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 26.67, 3, 14565)
# (None, 'Vistara', 'UK-833', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 28.5, 3, 14565)
# (None, 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 11.75, 3, 14235)
# (None, 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 19.5, 3, 14250)
# (None, 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8.25, 3, 14618)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 14.67, 3, 14775)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 26.67, 3, 14775)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 28.25, 3, 14775)
# (None, 'Indigo', '6E-2338', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8, 3, 14744)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 13.75, 3, 15353)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 27.33, 3, 15353)
# (None, 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 28.42, 3, 15405)
# (None, 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Afternoon', 'Mumbai', 'Economy', 16.17, 3, 15090)
# (None, 'Indigo', '6E-7403', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 8.67, 3, 15232)
# (None, 'Indigo', '6E-607', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 10.17, 3, 15232)
# (None, 'Vistara', 'UK-953', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 3, 15720)
# (None, 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 3, 15720)
# (None, 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 30.08, 3, 15405)
# (None, 'Indigo', '6E-6722', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 3, 15720)
# (None, 'Indigo', '6E-184', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 4.17, 3, 15720)
# (None, 'Indigo', '6E-2154', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 9.25, 3, 15720)
# (None, 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Evening', 'Mumbai', 'Economy', 20.42, 3, 15825)
# (None, 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Evening', 'Mumbai', 'Economy', 24.83, 3, 15825)
# (None, 'Air_India', 'AI-801', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 29.33, 3, 16245)
# (None, 'Vistara', 'UK-855', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 20.08, 3, 16665)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.75, 3, 16718)
# (None, 'GO_FIRST', 'G8-165', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 8, 3, 16823)
# (None, 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 21.08, 3, 17190)
# (None, 'GO_FIRST', 'G8-191', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 8.92, 3, 16859)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.58, 3, 17243)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.17, 3, 17348)
# (None, 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.5, 3, 17136)
# (None, 'Air_India', 'AI-9843', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 9.75, 3, 17295)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 17.83, 3, 17978)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Morning', 'Mumbai', 'Economy', 18, 3, 18030)
# (None, 'Vistara', 'UK-837', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 18.25, 3, 18135)
# (None, 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 13.25, 3, 18135)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 11.17, 3, 18713)
# (None, 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.92, 3, 19238)
# (None, 'Air_India', 'AI-807', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.25, 3, 19605)
# (None, 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Morning', 'Mumbai', 'Economy', 19.08, 3, 19605)
# (None, 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.58, 3, 19920)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.58, 3, 21233)
# (None, 'Vistara', 'UK-847', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 27.58, 3, 21285)
# (None, 'GO_FIRST', 'G8-213', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 6.33, 3, 21899)
# (None, 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 22.83, 3, 22755)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 6, 3, 23228)
# (None, 'Air_India', 'AI-406', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 4.83, 3, 22965)
# (None, 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 11.33, 3, 23070)
# (None, 'GO_FIRST', 'G8-300', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 5.92, 3, 23491)
# (None, 'Air_India', 'AI-811', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 20.58, 3, 24225)
# (None, 'Air_India', 'AI-431', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 26.17, 3, 24225)
# (None, 'Air_India', 'AI-465', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 6.25, 3, 24435)
# (None, 'Air_India', 'AI-9809', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 25.83, 3, 25223)
# (None, 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 27.17, 3, 26325)
# (None, 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 23.83, 3, 27165)
# (None, 'Air_India', 'AI-877', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 6.42, 3, 29580)
# (None, 'Air_India', 'AI-512', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8.92, 3, 31260)
# (None, 'SpiceJet', 'SG-8709', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 4, 5953)
# (None, 'SpiceJet', 'SG-1089', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.25, 4, 5953)
# (None, 'SpiceJet', 'SG-1061', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 4, 5953)
# (None, 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 4, 5953)
# (None, 'SpiceJet', 'SG-1063', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 4, 5953)
# (None, 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 4, 5953)
# (None, 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 4, 5955)
# (None, 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 4, 5955)
# (None, 'Vistara', 'UK-985', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 4, 5955)
# (None, 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.25, 4, 5955)
# (None, 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 4, 5955)
# (None, 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 4, 5955)
# (None, 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 4, 5955)
# (None, 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.08, 4, 6060)
# (None, 'Vistara', 'UK-953', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 4, 6060)
# (None, 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 4, 5954)
# (None, 'GO_FIRST', 'G8-392', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 4, 5954)
# (None, 'GO_FIRST', 'G8-346', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 4, 5954)
# (None, 'GO_FIRST', 'G8-330', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 4, 5954)
# (None, 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 4, 5954)
# (None, 'GO_FIRST', 'G8-323', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 4, 5954)
# (None, 'Indigo', '6E-2054', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 4, 5955)
# (None, 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.17, 4, 5955)
# (None, 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 4, 5955)
# (None, 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 4, 5955)
# (None, 'SpiceJet', 'SG-8803', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.25, 4, 5955)
# (None, 'Indigo', '6E-218', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.25, 4, 5955)
# (None, 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 4, 5955)
# (None, 'Indigo', '6E-6722', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 4, 5955)
# (None, 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 4, 5955)
# (None, 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.5, 4, 5955)
# (None, 'Air_India', 'AI-868', 'Delhi', 'Evening', 'zero', 'Evening', 'Mumbai', 'Economy', 2, 4, 5955)
# (None, 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.08, 4, 5955)
# (None, 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 4, 5955)
# (None, 'Air_India', 'AI-805', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 4, 5955)
# (None, 'Air_India', 'AI-678', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.25, 4, 5955)
# (None, 'Air_India', 'AI-624', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 4, 5955)
# (None, 'AirAsia', 'I5-784', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 15.17, 4, 5949)
# (None, 'GO_FIRST', 'G8-1010', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 5.83, 4, 5954)
# (None, 'GO_FIRST', 'G8-191', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 8.92, 4, 5954)
# (None, 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 9.25, 4, 5954)
# (None, 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 11.75, 4, 5954)
# (None, 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 12.33, 4, 5954)
# (None, 'GO_FIRST', 'G8-119', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.17, 4, 5954)
# (None, 'GO_FIRST', 'G8-113', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 15.75, 4, 5954)
# (None, 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 3.75, 4, 5955)
# (None, 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.5, 4, 5955)
# (None, 'Indigo', '6E-2022', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 10.25, 4, 5955)
# (None, 'Indigo', '6E-5018', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 10.33, 4, 5955)
# (None, 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 10.42, 4, 5955)
# (None, 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.25, 4, 5955)
# (None, 'SpiceJet', 'SG-2277', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 25.75, 4, 5955)
# (None, 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning', 'Mumbai', 'Economy', 2.17, 4, 6139)
# (None, 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 4, 6165)
# (None, 'SpiceJet', 'SG-8483', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 13.25, 4, 6270)
# (None, 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 4, 6690)
# (None, 'Indigo', '6E-2092', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 5.33, 4, 6443)
# (None, 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 4, 6532)
# ...
# (None, 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 5.75, 6, 12150)
# (None, 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 5.83, 6, 12150)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 6, 6, 12150)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 6.5, 6, 12150)
# (None, 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 7.33, 6, 12150)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.58, 6, 12150)
# (None, 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 9.17, 6, 12150)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 11.17, 6, 12150)
# (None, 'Vistara', 'UK-807', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 11.58, 6, 12150)
# (None, 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 11.67, 6, 12150)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.17, 6, 12150)
# (None, 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 12.42, 6, 12150)
# (None, 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.67, 6, 12150)
# (None, 'Indigo', '6E-152', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 7.67, 6, 11814)
# (None, 'Air_India', 'AI-453', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 10.08, 6, 11900)
# (None, 'Air_India', 'AI-479', 'Delhi', 'Night', 'one', 'Afternoon', 'Mumbai', 'Economy', 16.5, 6, 11900)
# (None, 'Air_India', 'AI-451', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 25.92, 6, 11940)
# (None, 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 26.67, 6, 12308)
# (None, 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 11, 6, 12045)
# (None, 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.58, 6, 12150)
# (None, 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 11.33, 6, 12150)
# (None, 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 11.33, 6, 12150)
# (None, 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 14.92, 6, 12150)
# (None, 'Air_India', 'AI-807', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.25, 6, 12150)
# (None, 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Morning', 'Mumbai', 'Economy', 19.08, 6, 12150)
# (None, 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Morning', 'Mumbai', 'Economy', 22.83, 6, 12150)
# (None, 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 26.42, 6, 12150)
# (None, 'Air_India', 'AI-9857', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 7.25, 6, 12298)
# (None, 'SpiceJet', 'SG-3002', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 4.25, 6, 12360)
# (None, 'Air_India', 'AI-9915', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 21.25, 6, 12518)
# (None, 'Vistara', 'UK-833', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 7.33, 6, 12990)
# (None, 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.75, 6, 12990)
# (None, 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 7.58, 6, 13095)
# (None, 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 13.08, 6, 13095)
# (None, 'Vistara', 'UK-833', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 15.42, 6, 13095)
# (None, 'Vistara', 'UK-837', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.58, 6, 13095)
# (None, 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 10.42, 6, 12833)
# (None, 'Vistara', 'UK-839', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 9.08, 6, 13200)
# (None, 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 11.42, 6, 12990)
# (None, 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.83, 6, 12990)
# (None, 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Afternoon', 'Mumbai', 'Economy', 16.17, 6, 12990)
# (None, 'Vistara', 'UK-707', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 6, 6, 13410)
# (None, 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 16, 6, 13725)
# (None, 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 6.5, 6, 13830)
# (None, 'Vistara', 'UK-673', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 5, 6, 13988)
# (None, 'Vistara', 'UK-727', 'Delhi', 'Night', 'one', 'Afternoon', 'Mumbai', 'Economy', 16.5, 6, 14355)
# (None, 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 5.5, 6, 14565)
# (None, 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 19.5, 6, 14250)
# (None, 'Indigo', '6E-181', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 4.83, 6, 14255)
# (None, 'SpiceJet', 'SG-339', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 21.08, 6, 14328)
# (None, 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 23.83, 6, 14355)
# (None, 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 13.83, 6, 14880)
# (None, 'Air_India', 'AI-465', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 6.25, 6, 14670)
# (None, 'Air_India', 'AI-512', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 8.92, 6, 14670)
# (None, 'Air_India', 'AI-406', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 4.83, 6, 14775)
# (None, 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 13.25, 6, 14775)
# (None, 'Air_India', 'AI-839', 'Delhi', 'Night', 'one', 'Night', 'Mumbai', 'Economy', 26.5, 6, 14880)
# (None, 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 12.83, 6, 15615)
# (None, 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 30.08, 6, 15405)
# (None, 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 27.17, 6, 15615)
# (None, 'Indigo', '6E-607', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 10.17, 6, 15720)
# (None, 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 11.5, 6, 17925)
# (None, 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 10.92, 6, 18765)
# (None, 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 5.67, 6, 19500)
# (None, 'Air_India', 'AI-423', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 12.58, 6, 20445)
# (None, 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Evening', 'Mumbai', 'Economy', 20.42, 6, 21180)
# (None, 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Evening', 'Mumbai', 'Economy', 24.83, 6, 21180)
# (None, 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 7.25, 6, 22755)
# (None, 'Air_India', 'AI-439', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 11, 6, 22755)
# (None, 'Vistara', 'UK-847', 'Delhi', 'Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 27.58, 6, 23700)
# (None, 'SpiceJet', 'SG-8709', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 7, 5953)
# (None, 'SpiceJet', 'SG-1089', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.25, 7, 5953)
# (None, 'SpiceJet', 'SG-8803', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.25, 7, 5953)
# (None, 'SpiceJet', 'SG-1061', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 7, 5953)
# (None, 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 7, 5953)
# (None, 'SpiceJet', 'SG-1063', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 7, 5953)
# (None, 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 7, 5953)
# (None, 'Vistara', 'UK-981', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2, 7, 5955)
# (None, 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.08, 7, 5955)
# (None, 'Vistara', 'UK-975', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Vistara', 'UK-993', 'Delhi', 'Afternoon', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Vistara', 'UK-985', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Vistara', 'UK-953', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Vistara', 'UK-943', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.25, 7, 5955)
# (None, 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.25, 7, 5955)
# (None, 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 7, 5955)
# (None, 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 7, 5955)
# (None, 'Vistara', 'UK-941', 'Delhi', 'Evening', 'zero', 'Evening', 'Mumbai', 'Economy', 2.33, 7, 5955)
# (None, 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 7, 5955)
# (None, 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 7, 6060)
# (None, 'GO_FIRST', 'G8-392', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 7, 5954)
# (None, 'GO_FIRST', 'G8-346', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 7, 5954)
# (None, 'GO_FIRST', 'G8-330', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 7, 5954)
# (None, 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 7, 5954)
# (None, 'GO_FIRST', 'G8-323', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.33, 7, 5954)
# (None, 'Indigo', '6E-2054', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Indigo', '6E-2137', 'Delhi', 'Night', 'zero', 'Late_Night', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Indigo', '6E-6722', 'Delhi', 'Night', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 7, 5955)
# (None, 'Indigo', '6E-218', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.33, 7, 5955)
# (None, 'Air_India', 'AI-868', 'Delhi', 'Evening', 'zero', 'Evening', 'Mumbai', 'Economy', 2, 7, 5955)
# (None, 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.08, 7, 5955)
# (None, 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Air_India', 'AI-865', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Air_India', 'AI-805', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.17, 7, 5955)
# (None, 'Air_India', 'AI-678', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.25, 7, 5955)
# (None, 'Air_India', 'AI-624', 'Delhi', 'Evening', 'zero', 'Night', 'Mumbai', 'Economy', 2.25, 7, 5955)
# (None, 'GO_FIRST', 'G8-165', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 8, 7, 5954)
# (None, 'GO_FIRST', 'G8-199', 'Delhi', 'Afternoon', 'two_or_more', 'Night', 'Mumbai', 'Economy', 8.58, 7, 5954)
# (None, 'GO_FIRST', 'G8-191', 'Delhi', 'Morning', 'one', 'Evening', 'Mumbai', 'Economy', 8.92, 7, 5954)
# (None, 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 9.25, 7, 5954)
# (None, 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening', 'Mumbai', 'Economy', 11.75, 7, 5954)
# (None, 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 12.33, 7, 5954)
# (None, 'GO_FIRST', 'G8-719', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 14.25, 7, 5954)
# (None, 'GO_FIRST', 'G8-101', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 14.5, 7, 5954)
# (None, 'GO_FIRST', 'G8-119', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.17, 7, 5954)
# (None, 'GO_FIRST', 'G8-113', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 15.75, 7, 5954)
# (None, 'Air_India', 'AI-636', 'Delhi', 'Afternoon', 'one', 'Evening', 'Mumbai', 'Economy', 3.5, 7, 5955)
# (None, 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 3.75, 7, 5955)
# (None, 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.5, 7, 5955)
# (None, 'Indigo', '6E-2083', 'Delhi', 'Early_Morning', 'one', 'Morning', 'Mumbai', 'Economy', 5.42, 7, 5955)
# (None, 'Indigo', '6E-5018', 'Delhi', 'Afternoon', 'one', 'Night', 'Mumbai', 'Economy', 10.33, 7, 5955)
# (None, 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 15.25, 7, 5955)
# (None, 'SpiceJet', 'SG-8483', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 13.25, 7, 6060)
# (None, 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 7, 6165)
# (None, 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.5, 7, 6165)
# (None, 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning', 'Mumbai', 'Economy', 2.17, 7, 6349)
# (None, 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.17, 7, 6532)
# (None, 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening', 'Mumbai', 'Economy', 2.25, 7, 6532)
# (None, 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon', 'Mumbai', 'Economy', 2.17, 7, 6585)
# (None, 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening', 'Mumbai', 'Economy', 2.17, 7, 6585)
# (None, 'Indigo', '6E-2097', 'Delhi', 'Early_Morning', 'one', 'Afternoon', 'Mumbai', 'Economy', 7.58, 7, 6638)
# (None, 'Indigo', '6E-2092', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 5.33, 7, 6932)
# (None, 'Indigo', '6E-282', 'Delhi', 'Morning', 'two_or_more', 'Evening', 'Mumbai', 'Economy', 9.67, 7, 6953)
# (None, 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning', 'Mumbai', 'Economy', 2.33, 7, 7110)
# (None, 'Air_India', 'AI-481', 'Delhi', 'Morning', 'one', 'Night', 'Mumbai', 'Economy', 14.75, 7, 7468)
# (None, 'Air_India', 'AI-435', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 17.5, 7, 7468)
# (None, 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon', 'Mumbai', 'Economy', 26.67, 7, 8948)
# (None, 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Morning', 'Mumbai', 'Economy', 18.33, 7, 9105)
# (None, 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Morning', 'Mumbai', 'Economy', 21.83, 7, 9105)
# (None, 'GO_FIRST', 'G8-717', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.75, 7, 8869)
# (None, 'AirAsia', 'I5-773', 'Delhi', 'Evening', 'one', 'Early_Morning', 'Mumbai', 'Economy', 11.67, 7, 8869)
# (None, 'Air_India', 'AI-9887', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 15.17, 7, 9000)
# (None, 'Air_India', 'AI-469', 'Delhi', 'Early_Morning', 'one', 'Night', 'Mumbai', 'Economy', 17.83, 7, 9000)
# (None, 'Air_India', 'AI-9643', 'Delhi', 'Evening', 'one', 'Afternoon', 'Mumbai', 'Economy', 20.83, 7, 9053)
# (None, 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning', 'Mumbai', 'Economy', 10.42, 7, 9263)
# (None, 'Air_India', 'AI-531', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 24.75, 7, 9315)
# (None, 'Indigo', '6E-2168', 'Delhi', 'Evening', 'one', 'Night', 'Mumbai', 'Economy', 4.42, 7, 9373)

# %%
import pandas as pd
df = pd.read_csv('./Clean_Dataset.csv')
df = df[['airline', 'flight', 'source_city', 'departure_time',
       'stops', 'arrival_time', 'destination_city', 'class', 'duration',
       'days_left', 'price']]

# %%
df.shape
df.columns
# Out:
# Index(['airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price'],
#       dtype='object')

# %%
import pandas as pd
from sqlalchemy import create_engine
con = sqlite3.connect('flight_data.db')
cur = con.cursor()
# SQLite (local file)
engine = create_engine('sqlite:///flight_data.db')  # Creates 'flights.db' in your directory

# Push data to 'flight_data' table
df.to_sql('flight_data', engine, if_exists='append', index=False)

print("Data successfully inserted into flight_data table.")
con.commit()
con.close()
# Out:
# Data successfully inserted into flight_data table.

# %%
def fetch_airplane_data(query):
    con = sqlite3.connect('flight_data.db')
    cur = con.cursor()
    result = cur.execute(query).fetchall()
    # # print(cur.fetchall())
    # for x in cur.fetchall():
    #     print(x)
    cur.close()
    return result

# %%
def success(bool_flag):
    print('Called')
    if bool_flag == 'True':
        return True
    else:
        return False

# %%
airplane_data_function = {
    "name": "fetch_airplane_data",
    "description": ''' 
                Based on a sql query, the function returns the data from table flight_data.
    Columns details of flight_data Table
                1) Airline: The name of the airline company is stored in the airline column. It is a categorical feature having 6 different airlines.
            2) Flight: Flight stores information regarding the plane's flight code. It is a categorical feature.
            3) Source City: City from which the flight takes off. It is a categorical feature having 6 unique cities.
            4) Departure Time: This is a derived categorical feature obtained created by grouping time periods into bins. It stores information about the departure time and have 6 unique time labels.
            5) Stops: A categorical feature with 3 distinct values that stores the number of stops between the source and destination cities.
            6) Arrival Time: This is a derived categorical feature created by grouping time intervals into bins. It has six distinct time labels and keeps information about the arrival time.
            7) Destination City: City where the flight will land. It is a categorical feature having 6 unique cities.
            8) Class: A categorical feature that contains information on seat class; it has two distinct values: Business and Economy.
            9) Duration: A continuous feature that displays the overall amount of time it takes to travel between cities in hours.
            10)Days Left: This is a derived characteristic that is calculated by subtracting the trip date by the booking date.
            11) Price: Target variable stores information of the ticket price.
    ''',
    "parameters": {
        "type": "object",
        "properties": {
            "query": {
                "type": "string",
                "description": "query to for sql table to extract insights",
            },
        },
        "required": ["query"],
        "additionalProperties": False
    }
}

# %%
success_function = {
    "name": "success",
    "description": ''' if you are satisfied with data analysis return text 'True' else 'False' to run different set of query
    ''',
    "parameters": {
        "type": "object",
        "properties": {
            "query": {
                "type": "string",
                "description": "boolean to continue or stop querying the db",
            },
        },
        "required": ["bool_flag"],
        "additionalProperties": False
    }
}

# %%
def handle_tool_call(message):
    # print(message)
    # tool_call = message.tool_calls[0]
    response = []
    # stop_flag = False
    for tool_call in message.tool_calls:
        arguments = json.loads(tool_call.function.arguments)
        # print(arguments)
        
        query = arguments.get('query')
        output = fetch_airplane_data(query)
            
        response.append({
            "role": "tool",
            "content": json.dumps({"query": query,"output": output}),
            "tool_call_id": tool_call.id
        })
    print(response)
    return response, query

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    # print(messages)
    response = openai.chat.completions.create(model=MODEL, messages=messages, tools=tools)
    print(response)
    # print(tools)
    # print(response)
    if response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        print('Hi')
        multi_response, query, stop_flag = handle_tool_call(message)
        messages.append(message)
        for response in multi_response:
            messages.append(response)
        print(messages)
        response = openai.chat.completions.create(model=MODEL, messages=messages)
        print('------/n')
        print(response)
        print('------')
    return response.choices[0].message.content

# %%
system_message = "You are a Data Analyst with good SQL command working for Airline Company FirebaseAI. "
system_message += "Your role is to write sql query which can be used to extract data from fight_data db which has following information: 'airline', 'flight', 'source_city', \
                    'departure_time', 'stops', 'arrival_time', 'destination_city', 'class', 'duration', 'days_left','price' .\
                    You can iteratively run database database to answer questions which may require multiple runs. You must answer only using the DB"
system_message += "If you don't know the answer, say so."

# %%
tools = [{'type':'function', 'function':airplane_data_function}]

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7880
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7880/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ChatCompletion(id='chatcmpl-BnKtjZuN0bxKOo2h2Y8fuRCwcy8hp', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_JFOzfXlSi38ZWuQ5oHOJBXSc', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Chennai\' AND destination_city = \'Mumbai\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_AWyYPVqqAMOweUDQR8GyLuSu', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Delhi\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_xtk89d67G02DB8fro3W4mL11', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Hyderabad\'"}', name='fetch_airplane_data'), type='function')]))], created=1751098103, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_62a23a81ef', usage=CompletionUsage(completion_tokens=135, prompt_tokens=491, total_tokens=626, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Hi
# [{'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Chennai\' AND destination_city = \'Mumbai\'", "output": [[22765.849646605267]]}', 'tool_call_id': 'call_JFOzfXlSi38ZWuQ5oHOJBXSc'}, {'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Delhi\'", "output": [[18725.32000810318]]}', 'tool_call_id': 'call_AWyYPVqqAMOweUDQR8GyLuSu'}, {'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Hyderabad\'", "output": [[17347.288379073758]]}', 'tool_call_id': 'call_xtk89d67G02DB8fro3W4mL11'}]
# [{'role': 'system', 'content': "You are a Data Analyst with good SQL command working for Airline Company FirebaseAI. Your role is to write sql query which can be used to extract data from fight_data db which has following information: 'airline', 'flight', 'source_city',                     'departure_time', 'stops', 'arrival_time', 'destination_city', 'class', 'duration', 'days_left','price' .                    You can iteratively run database database to answer questions which may require multiple runs. You must answer only using the DBIf you don't know the answer, say so."}, {'role': 'user', 'content': 'avg price of chennai to mumbai, mumbai to delhi and delhi to hyderbad'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_JFOzfXlSi38ZWuQ5oHOJBXSc', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Chennai\' AND destination_city = \'Mumbai\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_AWyYPVqqAMOweUDQR8GyLuSu', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Delhi\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_xtk89d67G02DB8fro3W4mL11', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Hyderabad\'"}', name='fetch_airplane_data'), type='function')]), {'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Chennai\' AND destination_city = \'Mumbai\'", "output": [[22765.849646605267]]}', 'tool_call_id': 'call_JFOzfXlSi38ZWuQ5oHOJBXSc'}, {'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Delhi\'", "output": [[18725.32000810318]]}', 'tool_call_id': 'call_AWyYPVqqAMOweUDQR8GyLuSu'}, {'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Hyderabad\'", "output": [[17347.288379073758]]}', 'tool_call_id': 'call_xtk89d67G02DB8fro3W4mL11'}]
# ------/n
# ChatCompletion(id='chatcmpl-BnKtmgu67StBiJSxxqLISYd5bIxLh', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The average prices for the specified routes are as follows:\n\n- Chennai to Mumbai: ₹22,765.85\n- Mumbai to Delhi: ₹18,725.32\n- Delhi to Hyderabad: ₹17,347.29', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1751098106, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=CompletionUsage(completion_tokens=46, prompt_tokens=417, total_tokens=463, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ------
# ChatCompletion(id='chatcmpl-BnKu30mYDisVgxAsDKvkjpUNvyLlX', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_NrKSJv9mCjKQDGry0ewpxs59', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Chennai\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_yqNXABg16nKN5uGSJ7Mvz09E', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Mumbai\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_Llk7EpZqMhkwf2eMIYRIfu16', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Hyderabad\' AND destination_city = \'Delhi\'"}', name='fetch_airplane_data'), type='function')]))], created=1751098123, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_62a23a81ef', usage=CompletionUsage(completion_tokens=135, prompt_tokens=550, total_tokens=685, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Hi
# [{'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Chennai\'", "output": [[22781.89911154985]]}', 'tool_call_id': 'call_NrKSJv9mCjKQDGry0ewpxs59'}, {'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Mumbai\'", "output": [[19355.82981228334]]}', 'tool_call_id': 'call_yqNXABg16nKN5uGSJ7Mvz09E'}, {'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Hyderabad\' AND destination_city = \'Delhi\'", "output": [[17243.945685398543]]}', 'tool_call_id': 'call_Llk7EpZqMhkwf2eMIYRIfu16'}]
# [{'role': 'system', 'content': "You are a Data Analyst with good SQL command working for Airline Company FirebaseAI. Your role is to write sql query which can be used to extract data from fight_data db which has following information: 'airline', 'flight', 'source_city',                     'departure_time', 'stops', 'arrival_time', 'destination_city', 'class', 'duration', 'days_left','price' .                    You can iteratively run database database to answer questions which may require multiple runs. You must answer only using the DBIf you don't know the answer, say so."}, {'role': 'user', 'metadata': None, 'content': 'avg price of chennai to mumbai, mumbai to delhi and delhi to hyderbad', 'options': None}, {'role': 'assistant', 'metadata': None, 'content': 'The average prices for the specified routes are as follows:\n\n- Chennai to Mumbai: ₹22,765.85\n- Mumbai to Delhi: ₹18,725.32\n- Delhi to Hyderabad: ₹17,347.29', 'options': None}, {'role': 'user', 'content': 'what about return price?'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_NrKSJv9mCjKQDGry0ewpxs59', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Chennai\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_yqNXABg16nKN5uGSJ7Mvz09E', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Mumbai\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_Llk7EpZqMhkwf2eMIYRIfu16', function=Function(arguments='{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Hyderabad\' AND destination_city = \'Delhi\'"}', name='fetch_airplane_data'), type='function')]), {'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Chennai\'", "output": [[22781.89911154985]]}', 'tool_call_id': 'call_NrKSJv9mCjKQDGry0ewpxs59'}, {'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Mumbai\'", "output": [[19355.82981228334]]}', 'tool_call_id': 'call_yqNXABg16nKN5uGSJ7Mvz09E'}, {'role': 'tool', 'content': '{"query": "SELECT AVG(price) AS avg_price FROM flight_data WHERE source_city = \'Hyderabad\' AND destination_city = \'Delhi\'", "output": [[17243.945685398543]]}', 'tool_call_id': 'call_Llk7EpZqMhkwf2eMIYRIfu16'}]
# ------/n
# ChatCompletion(id='chatcmpl-BnKu6tpzeA2vlmC0hBT9A1iDBwvBb', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The average return prices for the specified routes are as follows:\n\n- Mumbai to Chennai: ₹22,781.90\n- Delhi to Mumbai: ₹19,355.83\n- Hyderabad to Delhi: ₹17,243.95', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1751098126, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=CompletionUsage(completion_tokens=47, prompt_tokens=476, total_tokens=523, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ------
# ChatCompletion(id='chatcmpl-BnKvH3tgsm3Y3mZxe21aLVOp9nfqQ', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_dPFQVJnnPHHj2rIDH6qdiixP', function=Function(arguments='{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Chennai\' AND destination_city = \'Mumbai\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_dZWEd3sGKH8TPanQDJznJrLa', function=Function(arguments='{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Delhi\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_UmOLga9X73Ub0yCU4tBkvIf1', function=Function(arguments='{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Hyderabad\'"}', name='fetch_airplane_data'), type='function')]))], created=1751098199, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_62a23a81ef', usage=CompletionUsage(completion_tokens=141, prompt_tokens=629, total_tokens=770, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Hi
# [{'role': 'tool', 'content': '{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Chennai\' AND destination_city = \'Mumbai\'", "output": [["AirAsia", 1830]]}', 'tool_call_id': 'call_dPFQVJnnPHHj2rIDH6qdiixP'}, {'role': 'tool', 'content': '{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Delhi\'", "output": [["AirAsia", 2336]]}', 'tool_call_id': 'call_dZWEd3sGKH8TPanQDJznJrLa'}, {'role': 'tool', 'content': '{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Hyderabad\'", "output": [["Vistara", 2022]]}', 'tool_call_id': 'call_UmOLga9X73Ub0yCU4tBkvIf1'}]
# [{'role': 'system', 'content': "You are a Data Analyst with good SQL command working for Airline Company FirebaseAI. Your role is to write sql query which can be used to extract data from fight_data db which has following information: 'airline', 'flight', 'source_city',                     'departure_time', 'stops', 'arrival_time', 'destination_city', 'class', 'duration', 'days_left','price' .                    You can iteratively run database database to answer questions which may require multiple runs. You must answer only using the DBIf you don't know the answer, say so."}, {'role': 'user', 'metadata': None, 'content': 'avg price of chennai to mumbai, mumbai to delhi and delhi to hyderbad', 'options': None}, {'role': 'assistant', 'metadata': None, 'content': 'The average prices for the specified routes are as follows:\n\n- Chennai to Mumbai: ₹22,765.85\n- Mumbai to Delhi: ₹18,725.32\n- Delhi to Hyderabad: ₹17,347.29', 'options': None}, {'role': 'user', 'metadata': None, 'content': 'what about return price?', 'options': None}, {'role': 'assistant', 'metadata': None, 'content': 'The average return prices for the specified routes are as follows:\n\n- Mumbai to Chennai: ₹22,781.90\n- Delhi to Mumbai: ₹19,355.83\n- Hyderabad to Delhi: ₹17,243.95', 'options': None}, {'role': 'user', 'content': 'which airline has cheapest price for chennai to mumbai, mumbai to delhi and delhi to hyderbad'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_dPFQVJnnPHHj2rIDH6qdiixP', function=Function(arguments='{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Chennai\' AND destination_city = \'Mumbai\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_dZWEd3sGKH8TPanQDJznJrLa', function=Function(arguments='{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Delhi\'"}', name='fetch_airplane_data'), type='function'), ChatCompletionMessageToolCall(id='call_UmOLga9X73Ub0yCU4tBkvIf1', function=Function(arguments='{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Hyderabad\'"}', name='fetch_airplane_data'), type='function')]), {'role': 'tool', 'content': '{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Chennai\' AND destination_city = \'Mumbai\'", "output": [["AirAsia", 1830]]}', 'tool_call_id': 'call_dPFQVJnnPHHj2rIDH6qdiixP'}, {'role': 'tool', 'content': '{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Mumbai\' AND destination_city = \'Delhi\'", "output": [["AirAsia", 2336]]}', 'tool_call_id': 'call_dZWEd3sGKH8TPanQDJznJrLa'}, {'role': 'tool', 'content': '{"query": "SELECT airline, MIN(price) as cheapest_price FROM flight_data WHERE source_city = \'Delhi\' AND destination_city = \'Hyderabad\'", "output": [["Vistara", 2022]]}', 'tool_call_id': 'call_UmOLga9X73Ub0yCU4tBkvIf1'}]
# ------/n
# ChatCompletion(id='chatcmpl-BnKvJGWQ3M9mwtia4AKvgyGYCLvuZ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The airlines with the cheapest prices for the specified routes are as follows:\n\n- Chennai to Mumbai: **AirAsia** with a price of ₹1,830\n- Mumbai to Delhi: **AirAsia** with a price of ₹2,336\n- Delhi to Hyderabad: **Vistara** with a price of ₹2,022', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1751098201, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=CompletionUsage(completion_tokens=68, prompt_tokens=565, total_tokens=633, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ------
